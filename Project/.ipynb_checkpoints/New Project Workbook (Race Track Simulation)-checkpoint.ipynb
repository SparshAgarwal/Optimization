# %% [markdown]
# # Race Track Optimization
# Sparsh Agarwal & Sam Lasch

# %% [markdown]
# # Table of Contents
#
# 1. [Introduction](#introduction)
# 2. [Mathematical Model](#mathematical)
# 3. [Solutions](#solution)
# 4. [Result and discussion](#results)
# 5. [Conclusion](#conclusion)
# 6. [Appendix](#appendix)

# %% [markdown]
# <a id="introduction"></a>
# # 1. Introduction
# ![alt text](data:image/jpeg;base64,... "Formula One Car Rounding A Curve")
#
# Our project idea focused on optimizing how a Formula one car would drive around a two-curve track. Specifically, given a fixed amount of time, and a track parameter; what is the optimal path that the car could would take around the curve. This gives us information on the minimum amount of time required for a racecar to navigate a track curve.
#
# This problem is based in formula one racing.  Formula one is the highest class of auto racing and has an estimated 2.9-billion-dollar investment in auto technology by the teams each year. ([Wikipedia](https://en.wikipedia.org/wiki/Formula_One)) Thus optimizing track routes can help improve driver efficiency, as well as car engineering, and improve the performance of both cars and racers. Navigating a curve is the hardest part of the track because corners are the main location where speed is lost. Thus, this problem of navigating curves is one of the primary problems related to racing. Formula One cars use a series of aerodynamic qualities to maximize turning speed with down forcing, which matches our model by allowing us to ignore air resistance on a curve.
#
# Our problem space included limits on turning ability, speed of the car, acceleration of the car, and friction applied to the car as it drives. These constraints ensure the car is forced to account in speed as it rounds a curve, and is not able to make impossibly sharp curves. We were able to adjust the direction so that the car would only be able to move in the forward direction and not be able to move in a direction opposite the wheel direction.
#
# We applied several mathematical functions that correlated real world Physical constraints to the model. These were gravity, friction, and Centripetal force. We ignored air resistance because of the magnitude of difficulty that would apply to the model. Also, it would mean considering the mechanics and dimensionality of car, which we are not taking into account. We consider the car a point mass. We gathered the general information from sources on the internet, then developed the equations and constraints to apply to the model. Our track data was created with using java code(appendix) and a bitmap image.
#
# We will elaborate on the formation of the mathematical equations and models that we applied. These will be iterative as we discuss each stage of our model design. Each stage acts as a building block for the previous, culminating in a model resembling model predictive control. Then we will address the solutions to each stage of our design, and their results.

# %% [markdown]
# <a id="mathematical"></a>
# # 2. Mathematical Model
# This problem deals with the physics involved in making a car move. Particularly we aim at providing the optimal path that a car should take on a race track ensuring that all the laws of physics and mechanical and gravitational constraints are satisfied.
#
# To create an apt mathematical model, we had to proceed in stages because the realistic motion of a car on a track consists of many interlinked equations and implementing them all at ones might produce error prone code.  Since we can use two different frames of reference for the motion (i.e. the inertial frame of reference where everything is in respect of car, and the track frame of reference where everything is in external frame of the track. We use the external frame of reference to make equations less complicated and to avoid dealing with trigonometric coordinates. Also, this was beneficial because the car itself has minimalistic features. Most of the constraints and features are associated with either the track or the motion itself. Stages in which we incremented the complexity of model are as follows, these will help understand the model.
#
# ### Stage 1:
# 4 essential 2D variables are introduced P(position), v(velocity) and AccDM(acceleration in direction of motion), AccCent(acceleration in centripital direction). Where each index along the row determines its value in that time istance. I.e. P[1,1] would tell what is the x coordinate of position at time of 1 sec and P[2,1] is the y location at time 1 sec. To make things simpler we move in time steps of 1 sec. Such that velocity at time T will be calculated using velocity at T-1 sec. Time is treated as an integral quantity and intermediate continuous values are ignored. The three equations responsible to make a car move on an arbitrary path with arbitrary velocity and acceleration are:
#
#         @constraint(m, v[1,t+1] == v[1,t] + AccDM[1,t]  + AccCent[1,t])
#         @constraint(m, v[2,t+1] == v[2,t] + AccDM[2,t]  + AccCent[2,t])
#         @constraint(m, P[1,t+1] == P[1,t] + v[1,t] + (.5)*(AccDM[1,t]  + AccCent[1,t]))
#         @constraint(m, P[2,t+1] == P[2,t] + v[2,t] + (.5)*(AccDM[2,t]  + AccCent[2,t]))
#
# These are derived from motion constraints, $v = u +at^2$ where velocity $v$ after time is the sum of initial velocity $u$ and acceleration $a$ multiplied by time $t$ squared. Position is derived from $S = ut + (1/2)at^2$, where $S$ is displacement, which is equal to sum of the distance traversed by initial velocity in time t $ut$ and the acceleration during that time multiplied by time squared $(1/2)at^2$. The time squared reduces to 1 because we are moving in time steps of 1 sec.
#
# After constraining the initial and final position, car can move from one place another (assuming velocity, AccDM and AccCent are allowed to take any values). We then can constraint the initial and final velocities, their direction vector, and the max and min values that they can achieve. We can also constraint the convex set of values that P can take to make sure that P stays in a certain area only.
#
# After applying these constraints and providing an arbitrary final k time stamp, the car can move keeping velocity, AccDM, AccCent and Position inside their constraints of max and min values, along with satisfying the laws of physics. If the final position cannot be reached then it means that the car needs more time than the given k to reach the destination given the following constraints.
#
#         @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= (cofla*g)^2)
#         @constraint(m, ((AccDM[1,t]^2)+(AccDM[2,t]^2)) <= (Thrust[t]- (coflo*g))^2)
#         @constraint(m, (v[1,t]^2)+(v[2,t]^2) <= maxv^2)
#
# $(coflo*g)$ is the frictional force which the track applies in the direction opposite to the direction of motion. $(cofla*g)$ is also the max centripetal acceleration that the track can provide depending on the physical relations of tires and track material. This limits how much a car turn at a specific velocity which is given by $cofla*g >=v^2/r$ where “r” is the max radius of circle on which the car can turn at velocity $v$. We do not need to define this constraint because the first constraint above along with velocity increment equation implicitly define this constraint. These three ensure that the velocity, AccDM and AccCent do not go above their specified values. We assume that their min and max limits as magnitudes are symmetric.
#
# We also need to make sure that $|AccCent| > 0$ only when either $|v|>0$ or $|AccDM|>0$ because centripetal force cannot work on a stationary body. This is implemented by
#
#     @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= 999999*(((v[1,t]^2)+(v[2,t]^2))+((AccDM[1,t]^2)+(AccDM[2,t]^2))))
#
# ### Stage 2:
# The previous stage treats the car as a hovercraft i.e. acceleration direction is independent of the direction of motion, but this is not the case with a car. A car can only produce acceleration in its current direction of motion. To turn, it uses the frictional force produced between tires and track, which is applied perpendicular to direction of motion. Here we try to make the hovercraft behave more like a car. Since AccDM is a function of the direction of motion vector. It can be defined as:
#
#         @NLconstraint(m, (P[1,t]-P[1,t-1])*AccCent[1,t] + (P[2,t]-P[2,t-1])*AccCent[2,t] == 0)
#                 where (P[1,t]-P[1,t-1]) defines the direction of motion
#
#         @NLconstraint(m, AccDM[1,t] == AccDMBeta[t]*(P[1,t]-P[1,t-1]))
#         @NLconstraint(m, AccDM[2,t] == AccDMBeta[t]*(P[2,t]-P[2,t-1]))
#
# Until now all the constraints were convex but to implement these physical equations we need nonlinear constraints. The first one keeps the AccCent perpendicular to direction of motion. The second and third constraints keep the AccDm along direction of motion. After applying these constraints, the car moves in a more realistic motion where the most of its motions are governed by the laws of physics (keeping in mind our assumptions.)
#
# ### Stage 3:
# Now since the car can work properly, we need to focus on track constraints, which keep the car on track. We already defined the enclosed convex set of possible position values before, but in order to be able to move along a certain path inside that convex set, we need position respective to time constraints. i.e. we need to make sure that at each second the car is within the track and is moving incrementally towards its desired route, instead of taking a suboptimal route. Here we have two problems, one is to guess what will be the probable position of the car at a certain time and to use that as a position constraint keeping in mind the physical constraints of motion. We had initially tried to use a csv here as a constraint by using the variable values as indexes in that csv, and employing a constraint that the indexes should only take values which ensure that the csv value at that position is a value assigned to either track, finish line or start line. This did not work because we cannot use a JUmp variable as an index as it does not have any value. We were able to work around this indexing in future stages, but were still unable to use the csv file as a constraint for the track.
#
# The second problem was to guess whether the car could even traverse our custom designed track given physical motion constraints, even with an extremely large finish time. The assumptions to these two problems contradict each other. If we assume that the car can eventually traverse the track in some arbitrary large finish time, it becomes hard to determine the position respective to time constraints for such large time stamps. And if we try to ensure that the car takes only limited time such that we can manually guess its position respective time constraints, then we would need to relax the physical laws of motions and their max/min values to allow the car to complete the track in a time close to the specified time. To solve this, we produce a tradeoff. We relax the AccCent and AccDM to allow them to take values larger that specified, minimizing the cost associated with how far they are from the optimal max/min value. We also relax the time that we think it would take for the car to compete the track by increasing the scarcity (minimizing 1 norm) of velocity and (Position-Finish) at some time stamps close to the final time stamp. These two costs together when minimized, create an objective that forces the car to take optimal path in min time while bringing the AccDM and AccCent closer to the optimal values. Here we can observe whether our track constraints and position respective time constraints are realistic given the physical motion constraints.
#
# Since we could not use the csv to create our constraints, we tried something similar to model predictive control. Where we set the next probable optimal value for position at the next time stamp using the previous time and solved the model again for the optimal path. For this we had to create an iterative model that would incrementally find next optimal steps for each time instance, while minimizing our combined cost function simultaneously.
#
# To accomplish this, we created a function that would cross the position stamps obtained from the model with those in csv, and pass the initial position stamps that are valid into the model. With each iteration, the function sends additional position stamps to the model as the possible optimal value to set at. After this the model is solved again and the new position values are cross checked with the csv. With each iteration we try to further make the constraints strict to reduce the 2 costs we are trying to minimize.
#
# For analysis purposes and troubleshooting, we store the parameter solution values for each variable and for each iteration. We will talk more about these in solution.
#
#
#
# ## 2.A. Assumptions
# The mass of the car and the dimensions of car are not considered in the model. The car is assumed to be a point mass with zero mass. This elliminated issues related with topling of car, banked tracks etc. Finish velocity and finish acceleration can be anything
#
# ## 2.B. Model
# ##### Stage 1 (Basic):
# Car moves in a straight line as hovercraft. This is a Qp problem
#
# ###### Parameter definition:
# $coflo =$ coeffecient of friction longitudnal(in direction of motion)
#
# $cofla =$ coeffecient of friction lattitudnal(perpendicular to direction of motion of the front tyers when they turn)
#
# $g =$ gravitational pull in m/sec^2
#
# $maxacc = $ max acc in m/sec^2
#
# $maxv =$ max velocity in m/sec equivalent to 200km/hr
#
# $kstart =$ number of seconds
#
# $kiteration =$ Number of seconds incrementing kstart
#
# ###### Variable definition:
# $P[i,j] = $ Resulting position in x,y for i in x and y direction,$ \forall j \in kiteration$
#
# $V[i,j] = $ Velocities in x,y for i in x and y direction,$ \forall j \in kiteration$
#
# $Thrust[j] = $ Thruster input,$ \forall j \in kiteration$
#
# $AccDM[i,j] = $ Acceleration in the direction of motion for i in x and y direction,$ \forall j \in kiteration$
#
# $AccCent[i,j] = $ Acceleration Centripital for i in x and y direction, $ \forall j \in kiteration$
#
# ###### Constraint:
# $AccCent[1,t]^2 + AccCent[2,t]^2 \le  (cofla*g)^2,$ $\forall$ $t \in kiteration$
#
# $AccDM[1,t]^2 + AccDM[2,t]^2 \le  Thrust[t] - (coflo*g))^2,$ $\forall$ $t \in kiteration$
#
# $V[1,t]^2 + V[2,t]^2 \le  maxv^2,$ $\forall$ $t \in kiteration$
#
# $V[1,t+1] = V[1,t] + AccDM[1,t]  + AccCent[1,t],$ $\forall$ $t \in kiteration - 1$
#
# $V[2,t+1] = V[2,t] + AccDM[2,t]  + AccCent[2,t],$ $\forall$ $t \in kiteration - 1$
#
# $P[1,t+1] = P[1,t] + V[1,t] + (.5) * (AccDM[1,t]  + AccCent[1,t]),,$ $\forall$ $t \in kiteration - 1$
#
# $P[2,t+1] = P[2,t] + V[2,t] + (.5) * (AccDM[2,t]  + AccCent[2,t]),$ $\forall$ $t \in kiteration - 1$
#
# ###### Objective function
# $P[i,kiteration] = finishPos,$ sets the final position for i in x,y
#
#
# ##### Stage 2 :
# Car moves in a hypothetical constrained path (nonconvex) as hovercraft (get validity of position respective time constraints with relaxed physical motion constraints fbecause of turning) This is a Qp problem
#
# ###### AdditionalConstraint:
# The car is now constrained to a nonconvex track using position at time constraints
#
#
# ##### Stage 3 :
# Car moves in straight line as a car (with max/min and AccDM/AccCent directional constraints applied) This is a Qp problem
#
# ###### Additional Variable:
# $AccDMBeta[j] = $ Scaler of direction of motion to get the acceleration in the direction of motion ,$ \forall j \in kiteration$
#
#
# ###### Additional Constraint:
# $AccCent[1,t]^2 + AccCent[2,t]^2 \le 999999*( (V[1,t]^2 + V[2,t]^2)+ (AccDM[1,t]^2 + AccDM[2,t]^2) ),$ $ \forall $ $t > 1 \in kiteration$
#
# $(P[1,t]-P[1,t-1]) * AccCent[1,t] + (P[2,t]-P[2,t-1])*AccCent[2,t] = 0,$ $ \forall $ $t > 1 \in kiteration$
#
# $AccDM[1,t] = AccDMBeta[t]*(P[1,t]-P[1,t-1]),$ $ \forall $ $t > 1 \in kiteration$
#
# $AccDM[2,t] = AccDMBeta[t]*(P[2,t]-P[2,t-1]),$ $ \forall $ $t > 1 \in kiteration$
#
#
# ##### Stage 4 :
# Car moves in curved track as a car in a convex space race track while minimizing time to reach finish and the cost associated with how much its motion constraints are off from their limits in order to traverse. This is an Nonlinear problem
#
# ###### Additional Variable:
# $t2[i] =$ Positions variables that are at the final position, for $ \forall $ $i \in kiteration-extrakiteration$ to $kiteration$
#
# $t2v[i] =$ scarcity of velocity=0 at the end position, for $ \forall $ $i \in kiteration-extrakiteration$ to $kiteration$
#
#
# ###### Additional Constraint:
# $\sum_{i=kiteration-extrakiteration}^{kiteration} (P[l,i]-finishPos)^2 \le t2[i],$ for l in x,y
#
# $\sum_{i=kiteration-extrakiteration}^{kiteration} (P[l,i]-finishPos)^2 \ge t2[i],$ for l in x,y
#
# $\sum_{i=kiteration-extrakiteration}^{kiteration} (V[l,i]-[0,0])^2 \le t2v[i],$ for l in x,y
#
# $\sum_{i=kiteration-extrakiteration}^{kiteration} (V[l,i]-[0,0])^2 \ge t2v[i],$ for l in x,y
#
#
# ###### objective function
# $Min (\sum_{i=kiteration-extrakiteration}^{kiteration} t2[i]+t2v[i]) + (\sum_{i=1}^{kiteration} (AccCent[1,i]^2)+(AccCent[2,i]^2)-(cofla*g)^2) + (\sum_{i=1}^{kiteration}(AccDM[1,i]^2)+(AccDM[2,i]^2)-maxacc^2)$
#
# ##### Stage 5 :
# Car moves in curved track as car while minimizing time to reach finish and the cost associated with how much its motion constraints are off from their limits in order to traverse our hypothetical track. This is an Nonlinear problem
#
# ###### Additional Constraint:
# The car must move along our nonconvex track
#
# ##### Stage 6 :
# Model predective control for smoothing. This is an Nonlinear problem
#
# ###### objective function
# This stage utilized the same model as stage 5 but attempted to use a version of model predictive control to help smooth the optimal path. That involved increasing the time which would help minimize the cost as it relates to relaxation.

# %% [markdown]
# <a id="solution"></a>
# # 3. Solution

# %% [markdown]
# <a id="s1"></a>
# ## Stage 1
# Car moves in a straight line as hovercraft [Stage 1 Results and discussion](#r1)

# %%
using Gurobi, Cbc, Mosek, PyPlot, JuMP, Ipopt

raw = readcsv("Book1.csv");
trackx = length(raw[:,1])
tracky = length(raw[1,:])
raw[1,1] = 28


## Tyre specs
coflo = 0.2 #coeffecient of friction longitudnal(in direction of motion)
cofla = 0.4 #coeffecient of friction lattitudnal(perpendicular to direction of motion of the front tyers when they turn)


## formula one car specs all specs in meters and seconds
g = 9.8  # gravitational pull in m/sec^2
maxacc = 14.2 # max acc in m/sec^2
maxv = 103.55 # max velocity in m/sec equivalent to 200km/hr

    
## Start ad Finish constraints
kstart =15 #28 optimal
startPos = [50,1]
finishPos = [50, 650]
startVel = [0,0]
finishVel = [0,0]
startAccDM = [0,0]
startAccCent = [0,0]
finishAccDM = [0,0]


##model
m = Model(solver = GurobiSolver());

kiteration = kstart

## Basic variables and their constraints
@variable(m, P[1:2,1:kiteration])  # resulting position in x,y
@variable(m, v[1:2,1:kiteration])
@variable(m, -maxacc <= Thrust[1:kiteration] <= maxacc)  # thruster input
@variable(m, AccDM[1:2,1:kiteration])
@variable(m, AccCent[1:2,1:kiteration])


@constraint(m, P[:,1] .== startPos)
@constraint(m, v[:,1] .== startVel)
@constraint(m, AccCent[:,1] .== startAccCent)
# @constraint(m, AccDM[:,1] .== startAccDM)
@constraint(m, P[:,kiteration] .== finishPos)
# @constraint(m, v[:,k] .== finishVel)
# @constraint(m, AccDM[:,k] .== finishAccDM)

## motion constraints
for t in 1:kiteration
    @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= (cofla*g)^2)
    @constraint(m, ((AccDM[1,t]^2)+(AccDM[2,t]^2)) <= (Thrust[t]- (coflo*g))^2)
    @constraint(m, (v[1,t]^2)+(v[2,t]^2) <= maxv^2)
end

@constraint(m, AccDM[2,1] >= 0)
@constraint(m, AccDM[1,1] >= 0)
@constraint(m, AccDM[1,1] <= 0)
for t in 1:kiteration-1    
    @constraint(m, v[1,t+1] == v[1,t] + AccDM[1,t]  + AccCent[1,t])
    @constraint(m, v[2,t+1] == v[2,t] + AccDM[2,t]  + AccCent[2,t])  
    @constraint(m, P[1,t+1] == P[1,t] + v[1,t] + (.5)*(AccDM[1,t]  + AccCent[1,t])) 
    @constraint(m, P[2,t+1] == P[2,t] + v[2,t] + (.5)*(AccDM[2,t]  + AccCent[2,t]))     
end
solve(m)

## Plotting everything
#Plotting track (Position plots will also go in same figure)
figure(figsize=(11,14))
title("Track and Position")
#Track
rawNew = transpose(raw)
imshow(rawNew[:,:], cmap="gray")
legend(loc ="best")
axis((-50,1050,-50,1350));
#Position
    plot( getvalue(P[1,:]), getvalue(P[2,:]),"b.-", markersize =5)

figure(figsize=(12,4))
title("Acceleration centripital(green), DM(red), V(blue)")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "g-", markersize=2 )
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "r-", markersize=2 )
plot( getvalue((v[1,:].^2)+(v[2,:].^2)), "b-", markersize=2 )#, yscale = :log10)

figure(figsize=(12,4))
title("velocity magnitude")
plot( getvalue(v[1,:].^2+v[2,:].^2), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity x")
plot( getvalue(v[1,:]), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity y")
plot( getvalue(v[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDM magnitude")
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion x")
plot( getvalue(AccDM[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion y")
plot( getvalue(AccDM[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDM magnitude")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion x")
plot( getvalue(AccCent[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion y")
plot( getvalue(AccCent[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDMBeta")
plot( getvalue(AccDMBeta), "b-", markersize=2 );
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000430B6F28>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C2AEEB8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003A2516A0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000008066438>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000000802CBE0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F1B06D8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004B44048>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004BE38BA8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F137780>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C8F7198>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F9C8D30>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C2E6748>)
# Academic license - for non-commercial use only
# Optimize a model with 67 rows, 135 columns and 263 nonzeros
# Model has 45 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [4e+00, 4e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+01, 1e+01]
#   RHS range        [1e+00, 7e+02]
#   QRHS range       [4e+00, 1e+04]
# Presolve removed 15 rows and 32 columns
# Presolve time: 0.00s
# Presolved: 91 rows, 142 columns, 267 nonzeros
# Presolved model has 39 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 24
#  AA' NZ     : 3.760e+02
#  Factor NZ  : 9.710e+02
#  Factor Ops : 1.205e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   0.00000000e+00 -4.04000000e-01  2.89e+03 1.00e-01  1.39e+02     0s
#    1   0.00000000e+00 -1.52350980e+02  3.98e+01 5.96e-04  2.11e+00     0s
#    2   0.00000000e+00 -2.97768716e+01  4.98e+00 6.51e-05  2.81e-01     0s
#    3   0.00000000e+00 -4.06739528e+00  3.68e-06 2.77e-05  2.54e-02     0s
#    4   0.00000000e+00 -7.85727061e-03  4.05e-12 3.99e-08  4.93e-05     0s
#    5   0.00000000e+00 -8.64311067e-06  1.47e-12 4.39e-11  5.42e-08     0s
#    6   0.00000000e+00 -1.55387937e-08  4.38e-12 7.31e-12  1.02e-10     0s
#
# Barrier solved model in 6 iterations and 0.00 seconds
# Optimal objective 0.00000000e+00

# %% [markdown]
# <a id="s2"></a>
# ## Stage 2
# Car moves in a hypothetical constrained path (nonconvex) as hovercraft (get validity of position respective time constraints with relaxed physical motion constraints (because of turning) [Stage 2 Results and discussion](#r2)

# %%
using Gurobi, Cbc, Mosek, PyPlot, JuMP, Ipopt

raw = readcsv("Book1.csv");
trackx = length(raw[:,1])
tracky = length(raw[1,:])
raw[1,1] = 28


## Tyre specs
coflo = 0.2 #coeffecient of friction longitudnal(in direction of motion)
cofla = 0.4 #coeffecient of friction lattitudnal(perpendicular to direction of motion of the front tyers when they turn)


## formula one car specs all specs in meters and seconds
g = 9.8  # gravitational pull in m/sec^2
maxacc = 14.2 # max acc in m/sec^2
maxv = 103.55 # max velocity in m/sec equivalent to 200km/hr

    
## Start ad Finish constraints
kstart =28 #28 optimal
startPos = [50,1]
finishPos = [1000, 650]
startVel = [0,0]
finishVel = [0,0]
startAccDM = [0,0]
startAccCent = [0,0]
finishAccDM = [0,0]


##model
m = Model(solver = GurobiSolver())

kiteration = kstart

## Basic variables and their constraints
@variable(m, P[1:2,1:kiteration])  # resulting position in x,y
@variable(m, v[1:2,1:kiteration])
@variable(m, -4*maxacc <= Thrust[1:kiteration] <= maxacc)  # thruster input
@variable(m, AccDM[1:2,1:kiteration])
@variable(m, AccDMBeta[1:kiteration])
@variable(m, AccCent[1:2,1:kiteration])
@constraint(m, P[:,1] .== startPos)
@constraint(m, v[:,1] .== startVel)
@constraint(m, AccCent[:,1] .== startAccCent)
# @constraint(m, AccDM[:,1] .== startAccDM)
@constraint(m, P[:,kiteration] .== finishPos)
# @constraint(m, v[:,k] .== finishVel)
# @constraint(m, AccDM[:,k] .== finishAccDM)

## motion constraints
for t in 1:kiteration
    @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= (cofla*g)^2)
    @constraint(m, ((AccDM[1,t]^2)+(AccDM[2,t]^2)) <= (Thrust[t]- (coflo*g))^2)
    @constraint(m, (v[1,t]^2)+(v[2,t]^2) <= maxv^2)
end

@constraint(m, AccDM[2,1] >= 0)
@constraint(m, AccDM[1,1] >= 0)
@constraint(m, AccDM[1,1] <= 0)

for t in 1:kiteration-1    
    @constraint(m, v[1,t+1] == v[1,t] + AccDM[1,t]  + AccCent[1,t])
    @constraint(m, v[2,t+1] == v[2,t] + AccDM[2,t]  + AccCent[2,t])  
    @constraint(m, P[1,t+1] == P[1,t] + v[1,t] + (.5)*(AccDM[1,t]  + AccCent[1,t])) 
    @constraint(m, P[2,t+1] == P[2,t] + v[2,t] + (.5)*(AccDM[2,t]  + AccCent[2,t]))     
end

## old track position respective time constraints
for t in 1:13
    @constraint(m, P[1,t] >= 0)
    @constraint(m, P[1,t] <= 100)
    @constraint(m, P[2,t] >= 0)
    @constraint(m, P[2,t] <= 1300)
end
for t in 15:16
    @constraint(m, P[2,t] >= 1200)
end
for t in 18:22
    @constraint(m, P[1,t] >= 500)
    @constraint(m, P[1,t] <= 600)
    @constraint(m, P[2,t] >= 600)
    @constraint(m, P[2,t] <= 1300)
end
for t in 23:kiteration
    @constraint(m, P[2,t] <= 700)
    @constraint(m, P[2,t] >= 600)
end

solve(m)



## Plotting everything
#Plotting track (Position plots will also go in same figure)
figure(figsize=(11,14))
title("Track and Position")
#Track
rawNew = transpose(raw)
imshow(rawNew[:,:], cmap="gray")
legend(loc ="best")
axis((-50,1050,-50,1350));
#Position
    plot( getvalue(P[1,:]), getvalue(P[2,:]),"b.-", markersize =2)
figure(figsize=(12,4))
title("Acceleration centripital(green), DM(red), V(blue)")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "g-", markersize=2 )
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "r-", markersize=2 )
plot( getvalue((v[1,:].^2)+(v[2,:].^2)), "b-", markersize=2 )#, yscale = :log10)

figure(figsize=(12,4))
title("velocity magnitude")
plot( getvalue(v[1,:].^2+v[2,:].^2), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity x")
plot( getvalue(v[1,:]), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity y")
plot( getvalue(v[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDM magnitude squared")
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion x")
plot( getvalue(AccDM[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion y")
plot( getvalue(AccDM[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccCent magnitude squared")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion x")
plot( getvalue(AccCent[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion y")
plot( getvalue(AccCent[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDMBeta")
plot( getvalue(AccDMBeta), "b-", markersize=2 )
;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000428EFFD0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004B466D8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000042289198>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F98A358>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000041C8EC18>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003A4F94A8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000043556CC0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C7B7C18>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C317668>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004BE44A58>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000000805C860>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003A202EF0>)

# %% [markdown]
# <a id="s3"></a>
# ## Stage 3
# Car moves in straight line as a car (with max/min and AccDM/AccCent directional constraints applied) [Stage 3 Results and discussion](#r3)

# %%
using Gurobi, Cbc, Mosek, PyPlot, JuMP, Ipopt

raw = readcsv("Book1.csv");
trackx = length(raw[:,1])
tracky = length(raw[1,:])
raw[1,1] = 28


## Tyre specs
coflo = 0.2 #coeffecient of friction longitudnal(in direction of motion)
cofla = 0.4 #coeffecient of friction lattitudnal(perpendicular to direction of motion of the front tyers when they turn)


## formula one car specs all specs in meters and seconds
g = 9.8  # gravitational pull in m/sec^2
maxacc = 14.2 # max acc in m/sec^2
maxv = 103.55 # max velocity in m/sec equivalent to 200km/hr

    
## Start ad Finish constraints
kstart =14 #28 optimal
startPos = [50,1]
finishPos = [50, 650]
startVel = [0,0]
finishVel = [0,0]
startAccDM = [0,0]
startAccCent = [0,0]
finishAccDM = [0,0]


##model
m = Model(solver = IpoptSolver(print_level=0))

kiteration = kstart

## Basic variables and their constraints
@variable(m, P[1:2,1:kiteration])  # resulting position in x,y
@variable(m, v[1:2,1:kiteration])
@variable(m, -4*maxacc <= Thrust[1:kiteration] <= maxacc)  # thruster input
@variable(m, AccDM[1:2,1:kiteration])
@variable(m, AccDMBeta[1:kiteration])
@variable(m, AccCent[1:2,1:kiteration])
@constraint(m, P[:,1] .== startPos)
@constraint(m, v[:,1] .== startVel)
@constraint(m, AccCent[:,1] .== startAccCent)
# @constraint(m, AccDM[:,1] .== startAccDM)
@constraint(m, P[:,kiteration] .== finishPos)
# @constraint(m, v[:,k] .== finishVel)
# @constraint(m, AccDM[:,k] .== finishAccDM)

## motion constraints
for t in 1:kiteration
    @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= (cofla*g)^2)
    @constraint(m, ((AccDM[1,t]^2)+(AccDM[2,t]^2)) <= (Thrust[t]- (coflo*g))^2)
    @constraint(m, (v[1,t]^2)+(v[2,t]^2) <= maxv^2)
end
for t in 2:kiteration
    @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= 999999*(((v[1,t]^2)+(v[2,t]^2))+((AccDM[1,t]^2)+(AccDM[2,t]^2)))) #|AccCent| > 0 only if (|v| > 0 || |AccDm| >0)
end
for t in 2:kiteration
    @NLconstraint(m, (P[1,t]-P[1,t-1])*AccCent[1,t] + (P[2,t]-P[2,t-1])*AccCent[2,t] == 0)
    @NLconstraint(m, AccDM[1,t] == AccDMBeta[t]*(P[1,t]-P[1,t-1]))
    @NLconstraint(m, AccDM[2,t] == AccDMBeta[t]*(P[2,t]-P[2,t-1]))
end
@constraint(m, AccDM[2,1] >= 0)
@constraint(m, AccDM[1,1] >= 0)
@constraint(m, AccDM[1,1] <= 0)
for t in 1:kiteration-1    
    @constraint(m, v[1,t+1] == v[1,t] + AccDM[1,t]  + AccCent[1,t])
    @constraint(m, v[2,t+1] == v[2,t] + AccDM[2,t]  + AccCent[2,t])  
    @constraint(m, P[1,t+1] == P[1,t] + v[1,t] + (.5)*(AccDM[1,t]  + AccCent[1,t])) 
    @constraint(m, P[2,t+1] == P[2,t] + v[2,t] + (.5)*(AccDM[2,t]  + AccCent[2,t]))     
end

solve(m)

## Plotting everything
#Plotting track (Position plots will also go in same figure)
figure(figsize=(11,14))
title("Track and Position")
#Track
rawNew = transpose(raw)
imshow(rawNew[:,:], cmap="gray")
legend(loc ="best")
axis((-50,1050,-50,1350));
#Position
plot( getvalue(P[1,:]), getvalue(P[2,:]),"b.-", markersize =2)

figure(figsize=(12,4))
title("Acceleration centripital(green), DM(red), V(blue)")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "g-", markersize=2 )
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "r-", markersize=2 )
plot( getvalue((v[1,:].^2)+(v[2,:].^2)), "b-", markersize=2 )#, yscale = :log10)

figure(figsize=(12,4))
title("velocity magnitude")
plot( getvalue(v[1,:].^2+v[2,:].^2), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity x")
plot( getvalue(v[1,:]), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity y")
plot( getvalue(v[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDM magnitude")
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion x")
plot( getvalue(AccDM[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion y")
plot( getvalue(AccDM[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccCent magnitude")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion x")
plot( getvalue(AccCent[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion y")
plot( getvalue(AccCent[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDMBeta")
plot( getvalue(AccDMBeta), "b-", markersize=2 )
;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000043556B70>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C8C04A8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004226A8D0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003ED53908>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004BB0DA0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000000802A588>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003A1A34E0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000008066908>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000428E3470>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003A4B1748>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004F278D0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000041C7A208>)
# Academic license - for non-commercial use only
# Optimize a model with 205 rows, 280 columns and 583 nonzeros
# Model has 84 quadratic constraints
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [4e+00, 4e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+01, 6e+01]
#   RHS range        [1e+00, 1e+03]
#   QRHS range       [4e+00, 1e+04]
# Presolve removed 101 rows and 73 columns
# Presolve time: 0.00s
# Presolved: 182 rows, 285 columns, 540 nonzeros
# Presolved model has 78 second-order cone constraints
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 11
#  AA' NZ     : 7.660e+02
#  Factor NZ  : 2.042e+03
#  Factor Ops : 2.613e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   0.00000000e+00 -2.50219000e+02  4.23e+03 1.00e-01  2.39e+02     0s
#    1   0.00000000e+00 -6.44650865e+02  9.73e+01 9.32e-04  5.17e+00     0s
#    2   0.00000000e+00 -2.20951716e+02  2.68e+01 4.49e-05  1.27e+00     0s
#    3   0.00000000e+00 -7.21772753e+01  5.01e+00 5.54e-05  2.76e-01     0s
#    4   0.00000000e+00 -1.47922538e+01  3.28e-06 2.68e-05  3.78e-02     0s
#    5   0.00000000e+00 -1.62716433e-02  2.68e-11 2.95e-08  4.16e-05     0s
#    6   0.00000000e+00 -3.07949115e-05  5.02e-12 1.61e-09  8.04e-08     0s
#    7   0.00000000e+00 -5.51341489e-08  7.60e-12 3.49e-11  1.60e-10     0s
#
# Barrier solved model in 7 iterations and 0.00 seconds
# Optimal objective 0.00000000e+00

# %% [markdown]
# <a id="s4"></a>
# ## Stage 4
# Car moves in curved track as a car in a convex space race track while minimizing time to reach finish and the cost associated much its motion constraints are off from their limits in order to traverse the track [Stage 4 Results and discussion](#r4)

# %%
using Gurobi, Cbc, Mosek, PyPlot, JuMP, Ipopt

raw = readcsv("Book1.csv");
trackx = length(raw[:,1])
tracky = length(raw[1,:])
raw[1,1] = 28


## Tyre specs
coflo = 0.2 #coeffecient of friction longitudnal(in direction of motion)
cofla = 0.4 #coeffecient of friction lattitudnal(perpendicular to direction of motion of the front tyers when they turn)


## formula one car specs all specs in meters and seconds
g = 9.8  # gravitational pull in m/sec^2
maxacc = 14.2 # max acc in m/sec^2
maxv = 103.55 # max velocity in m/sec equivalent to 200km/hr

    
## Start ad Finish constraints
kstart =15 #28 optimal
extrak = 3 
startPos = [50,1]
finishPos = [550, 700]
startVel = [0,0]
finishVel = [0,0]
startAccDM = [0,0]
startAccCent = [0,0]
finishAccDM = [0,0]


##model
m = Model(solver = IpoptSolver(print_level=0))

kiteration = kstart
extrakiteration = extrak

## Basic variables and their constraints
@variable(m, P[1:2,1:kiteration])  # resulting position in x,y
@variable(m, v[1:2,1:kiteration])
@variable(m, -4*maxacc <= Thrust[1:kiteration] <= maxacc)  # thruster input
@variable(m, AccDM[1:2,1:kiteration])
@variable(m, AccDMBeta[1:kiteration])
@variable(m, AccCent[1:2,1:kiteration])
@constraint(m, P[:,1] .== startPos)
@constraint(m, v[:,1] .== startVel)
@constraint(m, AccCent[:,1] .== startAccCent)
# @constraint(m, AccDM[:,1] .== startAccDM)
@constraint(m, P[:,kiteration] .== finishPos)
# @constraint(m, v[:,k] .== finishVel)
# @constraint(m, AccDM[:,k] .== finishAccDM)
@NLexpression(m, AccCentripital, sum((AccCent[1,i]^2)+(AccCent[2,i]^2)-(cofla*g)^2 for i in 1:kiteration))
@NLexpression(m, AccDMcost, sum((AccDM[1,i]^2)+(AccDM[2,i]^2)-maxacc^2 for i in 1:kiteration))


## motion constraints
for t in 1:kiteration
    @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= 1500)
    @constraint(m, ((AccDM[1,t]^2)+(AccDM[2,t]^2)) <= (Thrust[t]- (coflo*g))^2)
    @constraint(m, (v[1,t]^2)+(v[2,t]^2) <= maxv^2)
end
    for t in 2:kiteration-extrakiteration
        @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= 999999*(((v[1,t]^2)+(v[2,t]^2))+((AccDM[1,t]^2)+(AccDM[2,t]^2)))) #|AccCent| > 0 only if (|v| > 0 || |AccDm| >0)
    end
for t in 2:kiteration
    @NLconstraint(m, (P[1,t]-P[1,t-1])*AccCent[1,t] + (P[2,t]-P[2,t-1])*AccCent[2,t] == 0)
    @NLconstraint(m, AccDM[1,t] == AccDMBeta[t]*(P[1,t]-P[1,t-1]))
    @NLconstraint(m, AccDM[2,t] == AccDMBeta[t]*(P[2,t]-P[2,t-1]))
end
@constraint(m, AccDM[2,1] >= 0)
@constraint(m, AccDM[1,1] >= 0)
@constraint(m, AccDM[1,1] <= 0)
for t in 1:kiteration-1    
    @constraint(m, v[1,t+1] == v[1,t] + AccDM[1,t]  + AccCent[1,t])
    @constraint(m, v[2,t+1] == v[2,t] + AccDM[2,t]  + AccCent[2,t])  
    @constraint(m, P[1,t+1] == P[1,t] + v[1,t] + (.5)*(AccDM[1,t]  + AccCent[1,t])) 
    @constraint(m, P[2,t+1] == P[2,t] + v[2,t] + (.5)*(AccDM[2,t]  + AccCent[2,t]))     
end

##minimize time and velocity in second (by maximizing scarcity of velocity=0 at the ends)
#finish
@variable(m, t2[kiteration-extrakiteration:kiteration])
@variable(m, t2v[kiteration-extrakiteration:kiteration])
for i in kiteration-extrakiteration:kiteration
    @constraint(m, sum((P[:,i]-finishPos).^2) <= t2[i] )
    @constraint(m, sum((P[:,i]-finishPos).^2) >= t2[i] )
    @constraint(m, sum((v[:,i]-[0,0]).^2) <= t2v[i] )
    @constraint(m, sum((v[:,i]-[0,0]).^2) >= t2v[i] )
end
@NLexpression(m, finishPosDis1Norm, sum(t2[i]+t2v[i] for i in kiteration-extrakiteration:kiteration))

## Track boundaries variables and constraints
## old track position respective time constraints
for t in 1:kiteration
    @constraint(m, P[1,t] >= 0)
    @constraint(m, P[1,t] <= 1050)
    @constraint(m, P[2,t] >= 0)
    @constraint(m, P[2,t] <= 1300)
end



@NLobjective(m, Min, AccCentripital + finishPosDis1Norm + AccDMcost)
solve(m)
    

## Plotting everything
#Plotting track (Position plots will also go in same figure)
figure(figsize=(11,14))
title("Track and Position")
#Track
rawNew = transpose(raw)
imshow(rawNew[:,:], cmap="gray")
legend(loc ="best")
axis((-50,1050,-50,1350));
#Position
plot( getvalue(P[1,:]), getvalue(P[2,:]),"b.-", markersize =2)


figure(figsize=(12,4))
title("Acceleration centripital(green), DM(red), V(blue)")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "g-", markersize=2 )
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "r-", markersize=2 )
plot( getvalue((v[1,:].^2)+(v[2,:].^2)), "b-", markersize=2 )#, yscale = :log10)

figure(figsize=(12,4))
title("velocity magnitude")
plot( getvalue(v[1,:].^2+v[2,:].^2), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity x")
plot( getvalue(v[1,:]), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity y")
plot( getvalue(v[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDM magnitude")
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion x")
plot( getvalue(AccDM[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion y")
plot( getvalue(AccDM[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccCent magnitude")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion x")
plot( getvalue(AccCent[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion y")
plot( getvalue(AccCent[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDMBeta")
plot( getvalue(AccDMBeta), "b-", markersize=2 )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003ED055C0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F12AF98>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C320C18>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000042289550>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003A202FD0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C8D4B38>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003A1E1240>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F1260F0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000427999B0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C9266D8>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003ED35438>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004BE2EC88>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000004C826C18>

# %% [markdown]
# <a id="s5"></a>
# ## Stage 5
# Car moves on a curved track as car while minimizing the time required to reach finish and the cost associated with how much  its motion constraints are off from their limits in order to traverse our hypothetical track (nonconvex space race track)[Stage 5 Results and discussion](#r5)

# %%
using Gurobi, Cbc, Mosek, PyPlot, JuMP, Ipopt

raw = readcsv("Book1.csv");
trackx = length(raw[:,1])
tracky = length(raw[1,:])
raw[1,1] = 28


## Tyre specs
coflo = 0.2 #coeffecient of friction longitudnal(in direction of motion)
cofla = 0.4 #coeffecient of friction lattitudnal(perpendicular to direction of motion of the front tyers when they turn)


## formula one car specs all specs in meters and seconds
g = 9.8  # gravitational pull in m/sec^2
maxacc = 14.2 # max acc in m/sec^2
maxv = 103.55 # max velocity in m/sec equivalent to 200km/hr

    
## Start ad Finish constraints
kstart = 55 #28 optimal
extrak = 3 
startPos = [50,1]
finishPos = [1000, 650]
startVel = [0,0]
finishVel = [0,0]
startAccDM = [0,0]
startAccCent = [0,0]
finishAccDM = [0,0]


##model
m = Model(solver = IpoptSolver(print_level=0))

kiteration = kstart
extrakiteration = extrak

## Basic variables and their constraints
@variable(m, P[1:2,1:kiteration])  # resulting position in x,y
@variable(m, v[1:2,1:kiteration])
@variable(m, -4*maxacc <= Thrust[1:kiteration] <= maxacc)  # thruster input
@variable(m, AccDM[1:2,1:kiteration])
@variable(m, AccDMBeta[1:kiteration])
@variable(m, AccCent[1:2,1:kiteration])
@constraint(m, P[:,1] .== startPos)
@constraint(m, v[:,1] .== startVel)
@constraint(m, AccCent[:,1] .== startAccCent)
# @constraint(m, AccDM[:,1] .== startAccDM)
@constraint(m, P[:,kiteration] .== finishPos)
# @constraint(m, v[:,k] .== finishVel)
# @constraint(m, AccDM[:,k] .== finishAccDM)
@NLexpression(m, AccCentripital, sum((AccCent[1,i]^2)+(AccCent[2,i]^2)-(cofla*g)^2 for i in 1:kiteration))
@NLexpression(m, AccDMcost, sum((AccDM[1,i]^2)+(AccDM[2,i]^2)-maxacc^2 for i in 1:kiteration))


## motion constraints
for t in 1:kiteration
    @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= 1500)
    @constraint(m, ((AccDM[1,t]^2)+(AccDM[2,t]^2)) <= (Thrust[t]- (coflo*g))^2)
    @constraint(m, (v[1,t]^2)+(v[2,t]^2) <= maxv^2)
end
    for t in 2:kiteration-extrakiteration
        @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= 999999*(((v[1,t]^2)+(v[2,t]^2))+((AccDM[1,t]^2)+(AccDM[2,t]^2)))) #|AccCent| > 0 only if (|v| > 0 || |AccDm| >0)
    end
for t in 2:kiteration
    @NLconstraint(m, (P[1,t]-P[1,t-1])*AccCent[1,t] + (P[2,t]-P[2,t-1])*AccCent[2,t] == 0)
    @NLconstraint(m, AccDM[1,t] == AccDMBeta[t]*(P[1,t]-P[1,t-1]))
    @NLconstraint(m, AccDM[2,t] == AccDMBeta[t]*(P[2,t]-P[2,t-1]))
end
@constraint(m, AccDM[2,1] >= 0)
@constraint(m, AccDM[1,1] >= 0)
@constraint(m, AccDM[1,1] <= 0)
for t in 1:kiteration-1    
    @constraint(m, v[1,t+1] == v[1,t] + AccDM[1,t]  + AccCent[1,t])
    @constraint(m, v[2,t+1] == v[2,t] + AccDM[2,t]  + AccCent[2,t])  
    @constraint(m, P[1,t+1] == P[1,t] + v[1,t] + (.5)*(AccDM[1,t]  + AccCent[1,t])) 
    @constraint(m, P[2,t+1] == P[2,t] + v[2,t] + (.5)*(AccDM[2,t]  + AccCent[2,t]))     
end

##minimize time and velocity in second (by maximizing scarcity of velocity=0 at the ends)
#finish
@variable(m, t2[kiteration-extrakiteration:kiteration])
@variable(m, t2v[kiteration-extrakiteration:kiteration])
for i in kiteration-extrakiteration:kiteration
    @constraint(m, sum((P[:,i]-finishPos).^2) <= t2[i] )
    @constraint(m, sum((P[:,i]-finishPos).^2) >= t2[i] )
    @constraint(m, sum((v[:,i]-[0,0]).^2) <= t2v[i] )
    @constraint(m, sum((v[:,i]-[0,0]).^2) >= t2v[i] )
end
@NLexpression(m, finishPosDis1Norm, sum(t2[i]+t2v[i] for i in kiteration-extrakiteration:kiteration))

## Track boundaries variables and constraints
## old track position respective time constraints
for t in 1:20
    @constraint(m, P[1,t] >= 0)
    @constraint(m, P[1,t] <= 100)
    @constraint(m, P[2,t] >= 0)
    @constraint(m, P[2,t] <= 1300)
end
for t in 24:28
    @constraint(m, P[2,t] >= 1200)
end
for t in 33:42
    @constraint(m, P[1,t] >= 500)
    @constraint(m, P[1,t] <= 600)
    @constraint(m, P[2,t] >= 600)
    @constraint(m, P[2,t] <= 1300)
end
for t in 43:kiteration
    @constraint(m, P[2,t] <= 700)
    @constraint(m, P[2,t] >= 600)
end

@NLobjective(m, Min, AccCentripital + finishPosDis1Norm + AccDMcost)
solve(m)
    

## Plotting everything
#Plotting track (Position plots will also go in same figure)
figure(figsize=(11,14))
title("Track and Position")
#Track
rawNew = transpose(raw)
imshow(rawNew[:,:], cmap="gray")
legend(loc ="best")
axis((-50,1050,-50,1350));
#Position
plot( getvalue(P[1,:]), getvalue(P[2,:]),"b.-", markersize =5)
plot( getvalue(P[1,10]), getvalue(P[2,10]),"r.", markersize =5)
plot( getvalue(P[1,20]), getvalue(P[2,:20]),"r.-", markersize =5)
plot( getvalue(P[1,30]), getvalue(P[2,30]),"r.", markersize =5)
plot( getvalue(P[1,40]), getvalue(P[2,:40]),"r.-", markersize =5)
plot( getvalue(P[1,50]), getvalue(P[2,50]),"r.", markersize =5)
plot( getvalue(P[1,55]), getvalue(P[2,:55]),"r.-", markersize =5)

figure(figsize=(12,4))
title("Acceleration centripital(green), DM(red), V(blue)")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "g-", markersize=2 )
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "r-", markersize=2 )
plot( getvalue((v[1,:].^2)+(v[2,:].^2)), "b-", markersize=2 )#, yscale = :log10)

figure(figsize=(12,4))
title("velocity magnitude")
plot( getvalue(v[1,:].^2+v[2,:].^2), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity x")
plot( getvalue(v[1,:]), "b.-", markersize=2 )

figure(figsize=(12,4))
title("velocity y")
plot( getvalue(v[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDM magnitude")
plot( getvalue((AccDM[1,:].^2)+(AccDM[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion x")
plot( getvalue(AccDM[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in direction of motion y")
plot( getvalue(AccDM[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccCent magnitude")
plot( getvalue((AccCent[1,:].^2)+(AccCent[2,:].^2)), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion x")
plot( getvalue(AccCent[1,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("Acceleration in centripital of motion y")
plot( getvalue(AccCent[2,:]), "b-", markersize=2 )

figure(figsize=(12,4))
title("AccDMBeta")
plot( getvalue(AccDMBeta), "b-", markersize=2 )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C8D4400>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000043556CC0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000042212940>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F9639B0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F98FD68>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004228BA20>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C7B7828>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000008060C50>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000007FC51D0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000004B7F898>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000008012CC0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000041D71D30>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000004BE383C8>

# %% [markdown]
# <a id="s6"></a>
# ## Stage 6
# (Model predective control included) [Stage 6 Results and discussion](#r6)

# %%
using Gurobi, Cbc, Mosek, PyPlot, JuMP, Ipopt


##track specs
starttrack = 28
finishtrack = 242
maintrack = 0
backgroundtrack = 255


## Tyre specs
coflo = 0.2 #coeffecient of friction longitudnal(in direction of motion)
cofla = 0.4 #coeffecient of friction lattitudnal(perpendicular to direction of motion of the front tyers when they turn)


## formula one car specs all specs in meters and seconds
g = 9.8  # gravitational pull in m/sec^2
maxacc = 14.2 # max acc in m/sec^2
maxv = 103.55 # max velocity in m/sec equivalent to 200km/hr

    
## Start ad Finish constraints
kstart =55 #28 optimal
extrak = 3 #probable extra time seconds
startPos = [50,1]
finishPos = [1000, 650]
startVel = [0,0]
finishVel = [0,0]
startAccDM = [0,0]
startAccCent = [0,0]
finishAccDM = [0,0]


function FindPath(CorPos,iterationsSet)
    ##model
    m = Model(solver = IpoptSolver(print_level=0))
    
    kstarttemp = kstart
    extraktemp = extrak
    for i in 1:iterationsSet
        kstarttemp = kstarttemp*1.1
        extraktemp = extraktemp*1.1
    end
    kiteration = round(Int64,kstarttemp) #28 optimal
    extrakiteration = round(Int64,extraktemp) #
    
    ## Basic variables and their constraints
    @variable(m, P[1:2,1:kiteration])  # resulting position in x,y
    @variable(m, v[1:2,1:kiteration])
    @variable(m, -4*maxacc <= Thrust[1:kiteration] <= maxacc)  # thruster input
    @variable(m, AccDM[1:2,1:kiteration])
    @variable(m, AccDMBeta[1:kiteration])
    @variable(m, AccCent[1:2,1:kiteration])
    @constraint(m, P[:,1] .== startPos)
    @constraint(m, v[:,1] .== startVel)
    @constraint(m, AccCent[:,1] .== startAccCent)
    # @constraint(m, AccDM[:,1] .== startAccDM)
    @constraint(m, P[:,kiteration] .== finishPos)
    # @constraint(m, v[:,k] .== finishVel)
    # @constraint(m, AccDM[:,k] .== finishAccDM)
    # @NLexpression(m, finishDistance, sum((P[i,k]-finishPos[i])^2 for i in 1:2))
    @NLexpression(m, AccCentripital, sum((AccCent[1,i]^2)+(AccCent[2,i]^2)-(cofla*g)^2 for i in 1:kiteration))
    @NLexpression(m, AccDMcost, sum((AccDM[1,i]^2)+(AccDM[2,i]^2)-maxacc^2 for i in 1:kiteration))

    
    ## motion constraints
    for t in 1:kiteration
        @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= 1500) # (cofla*g)^2 = 15.3664
        @constraint(m, ((AccDM[1,t]^2)+(AccDM[2,t]^2)) <= (Thrust[t]- (coflo*g))^2)
        @constraint(m, (v[1,t]^2)+(v[2,t]^2) <= maxv^2)
    end
    for t in 2:kiteration-extrakiteration
        @constraint(m, (AccCent[1,t]^2)+(AccCent[2,t]^2) <= 999999*(((v[1,t]^2)+(v[2,t]^2))+((AccDM[1,t]^2)+(AccDM[2,t]^2)))) #|AccCent| > 0 only if (|v| > 0 || |AccDm| >0)
    end
    for t in 2:kiteration
        @NLconstraint(m, (P[1,t]-P[1,t-1])*AccCent[1,t] + (P[2,t]-P[2,t-1])*AccCent[2,t] == 0)
        @NLconstraint(m, AccDM[1,t] == AccDMBeta[t]*(P[1,t]-P[1,t-1]))
        @NLconstraint(m, AccDM[2,t] == AccDMBeta[t]*(P[2,t]-P[2,t-1]))
    end
    @constraint(m, AccDM[2,1] >= 0)
    @constraint(m, AccDM[1,1] >= 0)
    @constraint(m, AccDM[1,1] <= 0)
    for t in 1:kiteration-1    
        @constraint(m, v[1,t+1] == v[1,t] + AccDM[1,t]  + AccCent[1,t])
        @constraint(m, v[2,t+1] == v[2,t] + AccDM[2,t]  + AccCent[2,t])  
        @constraint(m, P[1,t+1] == P[1,t] + v[1,t] + (.5)*(AccDM[1,t]  + AccCent[1,t])) 
        @constraint(m, P[2,t+1] == P[2,t] + v[2,t] + (.5)*(AccDM[2,t]  + AccCent[2,t]))     
    end

    
    ##minimize time and velocity in second (by maximizing scarcity of velocity=0 at the ends)    
    #finish
    @variable(m, t2[kiteration-extrakiteration:kiteration])
    @variable(m, t2v[kiteration-extrakiteration:kiteration])
    for i in kiteration-extrakiteration:kiteration
        @constraint(m, sum((P[:,i]-finishPos).^2) <= t2[i] )
        @constraint(m, sum((P[:,i]-finishPos).^2) >= t2[i] )
        @constraint(m, sum((v[:,i]-[0,0]).^2) <= t2v[i] )
        @constraint(m, sum((v[:,i]-[0,0]).^2) >= t2v[i] )
    end
    @NLexpression(m, finishPosDis1Norm, sum(t2[i]+t2v[i] for i in kiteration-extrakiteration:kiteration))

    ## Track boundaries variables and constraints
    ## old track position respective time constraints
for t in 1:kiteration
    @constraint(m, P[1,t] >= 0)
    @constraint(m, P[1,t] <= 1050)
    @constraint(m, P[2,t] >= 0)
    @constraint(m, P[2,t] <= 1300)
end
    
for t in round(Int64,(1*kiteration)/kstart):round(Int64,(20*kiteration)/kstart)
    @constraint(m, P[1,t] >= 0)
    @constraint(m, P[1,t] <= 100)
    @constraint(m, P[2,t] >= 0)
    @constraint(m, P[2,t] <= 1300)
end
for t in round(Int64,(24*kiteration)/kstart):round(Int64,(28*kiteration)/kstart)
    @constraint(m, P[2,t] >= 1200)
end
for t in round(Int64,(33*kiteration)/kstart):round(Int64,(42*kiteration)/kstart)
    @constraint(m, P[1,t] >= 500)
    @constraint(m, P[1,t] <= 600)
    @constraint(m, P[2,t] >= 600)
    @constraint(m, P[2,t] <= 1300)
end
for t in round(Int64,(43*kiteration)/kstart):kiteration
    @constraint(m, P[2,t] <= 700)
    @constraint(m, P[2,t] >= 600)
end

    # new csv stuff (mostly helps for smoothing when time increases to reduce centripital force)
    for i in 1:iterationsSet
        temp = round(Int64,CorPos[1,i])
        if temp == 0
            temp = temp+1
        end
        for ksets in temp:round(Int64,temp*1.1)
            setvalue(P[1,ksets], CorPos[2,i]) 
            setvalue(P[2,ksets], CorPos[3,i])  
        end
    end   

    @NLobjective(m, Min, AccCentripital + finishPosDis1Norm + AccDMcost)
    solve(m)
    
    
    ##function return stuff
    positions = getvalue(P)
    thrust = getvalue(Thrust)
    vel = getvalue(v)
    accDM = getvalue(AccDM)
    accCent= getvalue(AccCent)
    accDMBeta= getvalue(AccDMBeta)
    
    return(positions, vel,accDM,accCent,accDMBeta, thrust )
end

using JuMP, Gurobi, PyPlot
raw = readcsv("Book1.csv");
# print(raw[1032,650])
trackx = length(raw[:,1])
tracky = length(raw[1,:])
raw[1,1] = 28
iterations = 9

finalposSize =zeros(iterations) 
finalposSize[1] = kstart
for i in 2:iterations
    finalposSize[i] = finalposSize[i-1]*1.1
end
position = 150*ones(iterations,2,round(Int64, finalposSize[iterations]))
vel = 0*ones(iterations,2,round(Int64, finalposSize[iterations]))
thrust = 0*ones(iterations,round(Int64, finalposSize[iterations]))
accDM = 0*ones(iterations,2,round(Int64, finalposSize[iterations]))
accCent = 0*ones(iterations,2,round(Int64, finalposSize[iterations]))
accDMBeta = 0*ones(iterations,round(Int64, finalposSize[iterations]))

blankpos = [3;50;100]
(position[1,:,1:round(Int64,finalposSize[1])], 
    vel[1,:,1:round(Int64,finalposSize[1])], 
        accDM[1,:,1:round(Int64,finalposSize[1])], 
            accCent[1,:,1:round(Int64,finalposSize[1])],
                accDMBeta[1,1:round(Int64,finalposSize[1])],
                    thrust[1,1:round(Int64,finalposSize[1])]) = FindPath(blankpos,0)

for iteration = 2:iterations
    posCounter = 0

    for w in 1:length(position[iteration-1,1,:])
        tempx = round(Int64, position[iteration-1,1,w])
        tempy = round(Int64, position[iteration-1,2,w])
        if tempx == 0
            tempx = tempx+1
        end
        if tempy == 0
            tempy = tempy+1
        end

        if raw[tempx, tempy] < 255
            posCounter = posCounter+1
        end
    end
    if posCounter < length(position[iteration-1,1,:])
        CorPos = [zeros(posCounter)'; zeros(posCounter)';zeros(posCounter)']
        hits = 1
        for w in 1:length(position[iteration,1,:])
            tempx =  round(Int64, position[iteration-1,1,w]) 
            tempy =  round(Int64, position[iteration-1,2,w]) 
            if tempx == 0
                tempx = tempx+1
            end
            if tempy == 0
                tempy = tempy+1
            end
            posNumber = round(Int64, raw[tempx,tempy])
            if posNumber < 255
                CorPos[1,hits] = w
                CorPos[2,hits] = position[iteration-1,1,w]
                CorPos[3,hits] = position[iteration-1,2,w]
                hits = round(Int64, hits + 1)
            end
        end
        (position[iteration,:,1:round(Int64,finalposSize[iteration])], 
            vel[iteration,:,1:round(Int64,finalposSize[iteration])], 
                accDM[iteration,:,1:round(Int64,finalposSize[iteration])], 
                    accCent[iteration,:,1:round(Int64,finalposSize[iteration])],
                        accDMBeta[iteration,1:round(Int64,finalposSize[iteration])],
                            thrust[iteration,1:round(Int64,finalposSize[iteration])]) = FindPath(CorPos,iteration-1)
    end
end



## Plotting everything
#Plotting track (Position plots will also go in same figure)
figure(figsize=(11,14))
title("Track and Position")
#Track
rawNew = transpose(raw)
imshow(rawNew[:,:], cmap ="gray")
legend(loc ="best")
axis((-50,1050,-50,1350));
#position
for i = 1:iterations
    plot( position[i,1,1:round(Int64,finalposSize[i])], position[i,2,1:round(Int64,finalposSize[i])],label=string("Iteration = ", i))
end
legend(loc ="best")
# plot( position[1,1,:], position[1,2,:], "b.-", markersize=4 )

figure(figsize=(12,4))
title("Velocity Magnitude")
for i = 1:iterations
    plot( (vel[i,1,1:round(Int64,finalposSize[i])].^2)+(vel[i,2,1:round(Int64,finalposSize[i])].^2),label=string("Iteration = ", i))
end
legend(loc ="best")

figure(figsize=(12,4))
title("velocity x")
for i = 1:iterations
    plot( vel[i,1,1:round(Int64,finalposSize[i])],label=string("Iteration = ", i))
end
legend(loc ="best")

figure(figsize=(12,4))
title("velocity y")
for i = 1:iterations
    plot( vel[i,2,1:round(Int64,finalposSize[i])],label=string("Iteration = ", i))
end
legend(loc ="best")

figure(figsize=(12,4))
title("Acceleration DM Magnitude")
for i = 1:iterations
    plot( (accDM[i,1,1:round(Int64,finalposSize[i])].^2)+(accDM[i,2,1:round(Int64,finalposSize[i])].^2),label=string("Iteration = ", i))
end
legend(loc ="best")
axis((0,50,0,300));

figure(figsize=(12,4))
title("Acceleration in direction of motion x")
for i = 1:iterations
    plot( accDM[i,1,1:round(Int64,finalposSize[i])],label=string("Iteration = ", i))
end
legend(loc ="best")

figure(figsize=(12,4))
title("Acceleration in direction of motion y")
for i = 1:iterations
    plot( accDM[i,2,1:round(Int64,finalposSize[i])],label=string("Iteration = ", i))
end
legend(loc ="best")

figure(figsize=(12,4))
title("Acceleration Centripital Magnitude")
for i = 1:iterations
    plot( (accCent[i,1,1:round(Int64,finalposSize[i])].^2)+(accCent[i,2,1:round(Int64,finalposSize[i])].^2),label=string("Iteration = ", i))
end
legend(loc ="best")

figure(figsize=(12,4))
title("Acceleration in centripital of motion x")
for i = 1:iterations
    plot( accCent[i,1,1:round(Int64,finalposSize[i])],label=string("Iteration = ", i))
end
legend(loc ="best")


figure(figsize=(12,4))
title("Acceleration in centripital of motion y")
for i = 1:iterations
    plot( accCent[i,2,1:round(Int64,finalposSize[i])],label=string("Iteration = ", i))
end
legend(loc ="best")

figure(figsize=(12,4))
title("AccDMBeta")
for i = 1:iterations
    plot( accDMBeta[i,1:round(Int64,finalposSize[i])],label=string("Iteration = ", i))
end
legend(loc ="best")
axis((0,50,-5,5));
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000041C7A860>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000041BC3748>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000041BD6C50>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000041C36C18>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004283E6A0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004359F5C0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C77B860>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000004C804A90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000422262B0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000422CD320>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003F96DBE0>)

# %% [markdown]
# <a id="results"></a>
# # 4. Results and Discussion

# %% [markdown]
# <a id="r1"></a>
# ### Stage one:
# Our model in this stage was to build a car that would simply drive straight for 15 seconds. This model was the first step in building a model and was used to test the use of two acceleration variables. It also had constraints restricting the acceleration and velocity. Our constraints worked as it was only supposed to go straight with no deviation to left or right. Upon graphing the velocities and accelerations for both x and y, we see the y values increase just as they are supposed to. Curiously the x values also shift although they are not supposed to change. However, the values are very minute and are most likely the result of error in IPopt. The model proved to be working which allowed us to move on and implement further features.
# [Stage 1 Solution](#s1)
# <a id="r2"></a>
# ### Stage two:
# This built on the previous model and was then directed around the track with the same constraints as the previous stage. However, this model had to be able to constrain the position of the car to be within the track. The two major results from this are that our unrealistic time contraints will still work if we relax the AccDM and AccCent max/min values and associate a cost with it, and the other result is that since acceleration can act in any direction, it does not even use the centripetal force to turn and keeps it to zero. This is possible only because AccDM can work in directions other than in direction of motion to make the car turn. Also we got the car to move within the track. This was done by adding constraints to the position as it related to time. For example, in the first 13 seconds the car is unable to go left more than 100 meters, but after that time it is able to do so in order to round the curve. This stage found the optimal path for the car as it acted similar to a hovercraft and was constrained to be on the track. It is noted that the Acceleration in direction of motion values are relaxed and are four times the regular acceleration. This is because our track is made up and has no basis due to the unrealistic time constraints we implemented on the model. Thus, the acceleration was forced to be relaxed in order to find a solution. This is the cause of the high values found in the acceleration graphs.
# [Stage 2 Solution](#s2)
#  <a id="r3"></a>
# ### Stage 3:
# The previous stage allowed acceleration to act in any direction, much like a hovercraft. However, our car needed to apply acceleration only in the direction of motion. Thus, the third stage implemented constraints restricting the accretion to work in the direction of the car. Much like stage one the first step was to have it run in a straight line to test that it was functioning properly. However, these constraints were relaxed to allow the model to work properly. Future stages implement further constraints to rectify this. We also get to know that AccCent remains zero because it does not need to use the centripetal acceleration as it is not turning.
# [Stage 3 Solution](#s3)
#     <a id="r4"></a>
# ### Stage 4:
# This stage was about implementing the previous model in a convex space as it tried to reach the finish line. Thus, we did not apply track constraints to the problem. We constrained the model so that its turn ability was like a car, meaning it could not immediately go in any direction it sought and instead had to gradually curve in that direction. We were able to observe its restricted turning as it attempted to turn to the finish position. We also made the model attempt to both minimize the time to reach the finish, and the cost related to how far the constraints were from their limits. The acceleration centripetal graph proves that this function is working. The car turns slightly then straightens out. Thus, the centripetal force responsible for turning is raised only when the car is turning. Also, it does not remain zero as there is no other force which can help the car turn, so if it is forced to turn, the AccCent will have be nonzero to make the car turn. This is represented in the graphs.
# [Stage 4 Solution](#s4)
# <a id="r5"></a>
# ### Stage 5
# This stage applied the same constraints as the previous stage, but then applied them to the nonconvex track constraint. Much like stage 2 we constrained the position of the car with time as it moved along the track. This stage found the optimal path for the track, with minimized time, while also minimizing the costs associated with relaxation. Our model proves it is running optimally because it takes 51 seconds to run to final position but is given 55 seconds to do so. Thus, it optimizes our objective by maximizing the number of time steps with position at final position. It also reduced the values used in our relaxed variables. This is seen when comparing the accelerations from stage 5 to those in previous stages. By granting the model more time it is able to reduce the acceleration needed thus minimizing the costs associated with relaxation.
# [Stage 5 Solution](#s5)
# <a id="r6"></a>
# ### Stage 6:
# For stage six we attempted to implement a model predictive control system. We already got the position respective time constraints from stage 1 and we use that to smooth out the curve and reduce the costs associated with relaxations using our version of model predictive control. With each iteration we increase the time that car can take to trace the track. Since we have a valid working set of position respective time constraints, we can scale those time sections to increase the time car uses to trace the track while satisfying the position related time constraints. This solves our dual problems. We simplified a realistic track to an arbitrary one, then found the working time constraints and by converting those time constraints to ratios of total time taken, we can use them to allow the car to take more time. This solves our second problem as the AccDM and AccCent magnitudes come close to the expected min/max values. We can see this from the graphs that as the iterations proceed (and the finish time increases) we get a smoother function where the values are closer to their limits. We also use our version of model predictive control to enable IpOpt to get better solutions by setting the first k possible values of position in every incrementing iteration. This was done by using a csv file as a track. We would run the program giving us the optimal position values for the track. Then we verify these values with the track values in csv. The initial valid values are then used to set the initial probable position values in the solver to solve the model again in the next iteration producing a more optimal result.
# This stage summarizes out entire project where all the constraints are in the physical limits representing the laws and motion and bounded by the max/min values. The relaxation costs of AccDM and AccCent were larger when we used realistic values of AccDM and AccCent to trace track in unrealistic time. But when we allow it to take more time, these costs reduce and the optimal solution brings these values within the limits. We are also minimizing the time taken by car to traverse the track so that can be seen from the graph where v, AccDM and AccCent become zero after certain time, proving that it is minimizing the time it takes to traverse the track.
# [Stage 6 Solution](#s6)

# %% [markdown]
# <a id="conclusion"></a>
# # 5. Conclusion
#
# Conclusion it is hard to determine arbitrary optimal values of max/min limits of the car to find the optimal path on an arbitrary track. If we use realistic track constraints and realistic v, AccDM, and AccCent constraints. The solution can be optimized because we might be able to guess optimally the position respective probable time stamps. If we can guess that close enough, the model predictive control method will be able to provide a smooth curved traversal of the track along with medizing the cost associated with time stamps used and the amount by which AccDM and AccCent are off from their determined max/min values. Since the solution to two problems contradict each other, we need a well thought out optimally guessed position related time stamps or optimal max/mins for AccDM and AccCent so that the program can be solved to provide smooth traversal of track.
#
# But overall, we can observe from the results that to optimize the number of time stamps used, the solver tries to maintain the magnitude of velocity to travel maximum distance in every second. Because of this it takes the biggest curve it can take around a turn so that it does not have to reduce the velocity keeping in consideration the motion constraints. This is because of the limit to the max AccCent that the tires and track can provide.

# %% [markdown]
# <a id="appendix"></a>
# # 6. Appendix
# Our first task was to generate a two dimmensional array that would act as the race track. This involved a 2-d array filled with zeros. Then ones would be inserted into the array to be the track, with a starting line and finish line being 2's and 3's. We found the best way to do this was to use java code with a bitmap and write a script to convert the bitmap into a csv file.
# -Add java code to apeendix

# %%
import java.util.*;

public class ImageMain {

	public static void main(String[] args) throws IOException {
		Image image = ImageIO.read(new File("Image.bmp"));
		BufferedImage img = new BufferedImage(image.getWidth(null), image.getHeight(null), BufferedImage.TYPE_BYTE_GRAY);

		int w = img.getWidth();
		int h = img.getHeight();

		//Create array to of bitmap
		int[][] array = new int[w][h];
		Raster raster = ((BufferedImage) image).getData();
		for (int j = 0; j < w; j++) {
			for (int k = 0; k < h; k++) {
				array[j][k] = raster.getSample(j, k, 0);
			}
		}

		PrintWriter pw = new PrintWriter(new File("Track.csv"));
		StringBuilder sb = new StringBuilder();

		//Write file to csv
		for (int i = 0; i < array[0].length; i++) {
			for (int u = 0; u < array.length; u++) {
				sb.append(array[u][i]);
				sb.append(',');
				if(u == array[0].length-1){
					sb.append('\n');
				}
			}
		}
		pw.write(sb.toString());
		pw.close();
		System.out.println("done!");
	}
}
